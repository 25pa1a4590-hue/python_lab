# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a4590-hue/python_lab/blob/main/Excersice4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#operations in a list
S1=[1,22,30,18,90]
S2=[3,5,6,8,9]
print(S1+S2)
print(S1[0])
print(S1[2:5])
print(S2[0:2:5])
print(S2[::-2])
print(S1*2)
print(30 in S1)
for i in S2:
  print(i)
# Out:
# [1, 22, 30, 18, 90, 3, 5, 6, 8, 9]
# 1
# [30, 18, 90]
# [3]
# [9, 6, 3]
# [1, 22, 30, 18, 90, 1, 22, 30, 18, 90]
# True
# 3
# 5
# 6
# 8
# 9

# %%
#predefined functions in a list
L1=[2,5,8]


print(sum(L1))
print(max(L1))
print(min(L1))
print(len(L1))
# Out:
# 15
# 8
# 2
# 3

# %%
#list methods
S1=[1,2,3,18,'python']
S2=[4,5,6,'afrin']
S1.append("9")
print(S1)
S1.insert(2,1)
print(S1)
S1.pop(3)
print(S1)
S1.remove(18)
print(S1)
S1.extend(S2)
print(S1)
S=S1+S2
print(S)
S2=S1.copy()
print(S2)
S2[1:3]=['new','gen']
print(S2)
M1=[3,8,2,0,1,5]
M1.sort()
print(M1)
S1.count(3)
S1.index(2)
# Out:
# [1, 2, 3, 18, 'python', '9']
# [1, 2, 1, 3, 18, 'python', '9']
# [1, 2, 1, 18, 'python', '9']
# [1, 2, 1, 'python', '9']
# [1, 2, 1, 'python', '9', 4, 5, 6, 'afrin']
# [1, 2, 1, 'python', '9', 4, 5, 6, 'afrin', 4, 5, 6, 'afrin']
# [1, 2, 1, 'python', '9', 4, 5, 6, 'afrin']
# [1, 'new', 'gen', 'python', '9', 4, 5, 6, 'afrin']
# [0, 1, 2, 3, 5, 8]
# 1

# %%
#
S2[1:3]=['new','gen']
print(S2)
# Out:
# [4, 'new', 'gen', 'afrin']

# %%
#extend
S1.extend(S2)
print(S1)
S=S1+S2
print(S)
# Out:
# [1, 2, 1, 18, 'python', '9', 4, 'new', 'gen', 'afrin']
# [1, 2, 1, 18, 'python', '9', 4, 'new', 'gen', 'afrin', 4, 'new', 'gen', 'afrin']

# %%
#remove
S1.remove(18)
print(S1)
# Out:
# [1, 2, 1, 'python', '9', 4, 'new', 'gen', 'afrin']

# %%
#insert
S1.insert(2,1)
print(S1)
# Out:
# [1, 2, 1, 1, 18, 'python', '9', 4, 'new', 'gen', 'afrin']

# %%
#pop
S1.pop(3)
print(S1)
# Out:
# [1, 2, 1, 18, 'python', '9', 4, 'new', 'gen', 'afrin']

# %%
#copy
S2=S1.copy()
print(S2)
# Out:
# [1, 2, 1, 18, 'python', '9', 4, 'new', 'gen', 'afrin']

# %%
#sort
M1=[3,8,2,8,1,5]
M1.sort()
print(M1)
# Out:
# [1, 2, 3, 5, 8, 8]

# %%
#count
M1.count(8)
# Out:
# 2

# %%
#index
S1.index(2)
# Out:
# 1

# %%
#append
S1=[1,2,3,18,'python']
S2=[4,5,6,'afrin']
S1.append("9")
print(S1)
# Out:
# [1, 2, 3, 18, 'python', '9']
