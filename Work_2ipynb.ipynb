# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a4590-hue/python_lab/blob/main/Work_2ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10
b=6
print(a+b)
print(a%b)
print(a/b)
print(a//b)
print(a*b)
print(a**b)
print(a-b)
# Out:
# 16
# 4
# 1.6666666666666667
# 1
# 60
# 1000000
# 4

# %%
#camparision
a=15
b=5
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
print(a==b)
print(a!=b)
# Out:
# True
# False
# True
# False
# False
# True

# %%
#logical

# %%
a=15
b=2
c=5
print(a>b and c>b)
print(a<b or a>c)
print(not(a>b))
# Out:
# True
# True
# False

# %%
#Assignment
a=2
a-=3
a+=4
print(a)
a*=5
print(a)
a%=6
print(a)
a/=7
print(a)
a//=8
print(a)
a**=9
print(a)
# Out:
# 3
# 15
# 3
# 0.42857142857142855
# 0.0
# 0.0

# %%
a+=4
print(a)
# Out:
# 3

# %%
# Membership Operators

a = [1, 2, 3]

print( 1 in a)
print(2 in a)
print(3 not in a)
# Out:
# True
# True
# False

# %%
# Identity Operators

a = [1, 2, 3]
b = a
c = [1, 2, 3]

print(a is b)
print(a is c)
print(a == c)
print(a is not c)
# Out:
# True
# False
# True
# True

# %%
# Bitwise Operators

a = 10
b = 4

print(a & b)
print(a | b)
print(a ^ b)
print(~a)
print(a << 1)
print(a>>1)
# Out:
# 0
# 14
# 14
# -11
# 20
# 5
